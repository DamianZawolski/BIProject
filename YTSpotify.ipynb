# %% [markdown]
# Importing data from CSV

# %%
import pandas as pd
df = pd.read_csv(r'Spotify_Youtube.csv')
df.head()
# Out:
#    Unnamed: 0    Artist                                        Url_spotify  \
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1           1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2           2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3           3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4           4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Artist', 'Url_spotify', 'Track', 'Album', 'Album_type',
#        'Uri', 'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
#        'Comments', 'Description', 'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
sns.set_theme()
fig = plt.figure(figsize=(20, 15))
x = df.Views
y = df.Danceability
plt.scatter(x, y, color="red")

plt.title("Relation between Dancebility and Youtube views")
plt.xlabel("YT Views")
plt.ylabel(f"Dancebility")
plt.show()

# %%
fig.clear()
fig = plt.figure(figsize=(20, 15))
sns.set_theme()
x = df.Stream
y = df.Danceability
plt.scatter(x, y, color="green")
plt.title("Relation between Dancebility and Spotify streams")
plt.xlabel("Spotify streams")
plt.ylabel(f"Dancebility")
plt.show()

# %%
fig.clear()
fig = plt.figure(figsize=(20, 15))
sns.set_theme()
x = df.Stream
y = df.Views
plt.scatter(x, y, color="black")
plt.title("Relation between YT Views and Spotify streams")
plt.xlabel(f"Spotify Streams")
plt.ylabel("YT Views")
plt.show()

# %% [markdown]
# Powyższy wykres pokazuje nam, że nie ma jasnej relacji między wyświetleniami na YT a odsłuchami na Spotify

# %%
len(df), len(df.columns)
# Out:
# (20718, 28)
